# %%
import pickle

# %%
# read students.pickle
with open('students.pickle', 'rb') as f:
    students = pickle.load(f)

# %%
students
# Out:
# {'201708978': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201745741': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201733269': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201518849': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201704038': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201724915': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201639990': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
#  '201616881': [{'course': 'LIFE105-202324',
#    'url': 'https://canvas.liverpool.ac.uk/courses/67269/assignments'}],
# ...

# %%
len(students)
# Out:
# 407
